# %% [markdown]
# # Oops

# %%
class CSE: 
    def __init__(self, students):
        self.students = students
        
    def says(self):
        print(f'{self.students} students want bunk' )
        
# Creating objects
sec1 = CSE(67)
sec2 = CSE(65)

print(sec1.students)
print(sec2)

sec1.says()

# CSE --> Class
# sec1, sec2 --> objects
# Out:
# 67
# ...
# 67 students want bunk

# %%
#### modelling Coupons 

# Defining a
