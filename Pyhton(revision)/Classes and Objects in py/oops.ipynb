# %% [markdown]
# # Oops

# %%
class CSE: 
    def __init__(self, students):
        self.students = students
        
    def says(self):
        print(f'{self.students} students want bunk' )
        
# Creating objects
sec1 = CSE(67)
sec2 = CSE(65)

print(sec1.students)
print(sec2)

sec1.says()

# CSE --> Class
# sec1, sec2 --> objects
# Out:
# 67
# <__main__.CSE object at 0x0000017CFE1FA410>
# 67 students want bunk

# %%
#### modelling school bag 

# Defining a class for school bag 

class Bag:
    def __init__(self, student, books, capacity):
        self.students = student 
        self.books = books
        self.capacity = capacity
        
    def putBooks(self, newBooks):
        self.newBooks = newBooks
        self.books+=newBooks
        if self.books<self.capacity:
            print(f'{newBooks} are kept in the bag now total books in the bag are {self.books}')
        else:
            print(f"{self.books} books are reaching the capacity limit")
            
    def getBooks(self, )
