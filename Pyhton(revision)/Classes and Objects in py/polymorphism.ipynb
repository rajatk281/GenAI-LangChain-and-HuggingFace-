# %% [markdown]
# # Polymorphism

# %%
## Base class 
class Shape:
    def area(s):
        print('area of the shape ')
    
## Derived class
class Rectangle(Shape):
    def __init__(self, l, b):
        self.l = l
        self.b = b
    # def area(s):
    #     s.area = s.l*s.b
    #     print(f'area: {s.area}')
        
shape2 = Rectangle(4, 5)
shape2.area()
# Out:
# area of the shape
